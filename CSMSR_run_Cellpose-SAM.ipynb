# %% [markdown]
# ## Cellpose-SAM: superhuman generalization for cellular segmentation
#
# Marius Pachitariu, Michael Rariden, Carsen Stringer
#
# [paper](https://www.biorxiv.org/content/10.1101/2025.04.28.651001v1) | [code](https://github.com/MouseLand/cellpose)
#
# This notebook shows how to process your own 2D or 3D images, saved on Google Drive.
#
# This notebook is adapted from the notebook by Pradeep Rajasekhar, inspired by the [ZeroCostDL4Mic notebook series](https://github.com/HenriquesLab/ZeroCostDL4Mic/wiki).

# %% [markdown]
# ### Make sure you have GPU access enabled by going to Runtime -> Change Runtime Type -> Hardware accelerator and selecting GPU
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Mount your google drive
#
# Run this cell to connect your Google Drive to colab:
# * Click on the URL.
# * Sign in your Google Account.
#
# You will either have to:
# * copy the authorisation code and enter it into box below OR
# * in the new google colab, you can just click "Allow" and it should connect.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Then click on "Folder" icon on the Left, then click the refresh button. Your Google Drive folder should now be available here as "drive".
# (updated 3/26 TS)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Click on the triangle icon and it will allow you to access whole drive. Navigate to the folder containing your images. Once you are there, click on the three dots on the right of the folder and select "Copy Path"
#
# ![image.png](data:image/png;base64,...)
#
# Copy and paste this path in the **dir** string below

# %% [markdown]
# ### Install Cellpose-SAM

# %%
# !pip install git+https://www.github.com/mouseland/cellpose.git
# Out:
# Collecting git+https://www.github.com/mouseland/cellpose.git
#   Cloning https://www.github.com/mouseland/cellpose.git to /tmp/pip-req-build-ib4re6oa
#   Running command git clone --filter=blob:none --quiet https://www.github.com/mouseland/cellpose.git /tmp/pip-req-build-ib4re6oa
#   warning: redirecting to https://github.com/mouseland/cellpose.git/
#   Resolved https://www.github.com/mouseland/cellpose.git to commit cc9d63fca9983d47bb4028fcb19131ea95070705
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.12/dist-packages (from cellpose==4.0.9) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from cellpose==4.0.9) (1.16.3)
# Requirement already satisfied: natsort in /usr/local/lib/python3.12/dist-packages (from cellpose==4.0.9) (8.4.0)
# Requirement already satisfied: tifffile in /usr/local/lib/python3.12/dist-packages (from cellpose==4.0.9) (2026.2.24)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from cellpose==4.0.9) (4.67.3)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from cellpose==4.0.9) (0.25.0+cu128)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.12/dist-packages (from cellpose==4.0.9) (4.13.0.92)
# Collecting fastremap (from cellpose==4.0.9)
#   Downloading fastremap-1.17.7-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (10 kB)
# Collecting imagecodecs (from cellpose==4.0.9)
#   Downloading imagecodecs-2026.1.14-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (20 kB)
# Collecting roifile (from cellpose==4.0.9)
#   Downloading roifile-2026.2.10-py3-none-any.whl.metadata (6.0 kB)
# Collecting fill-voids (from cellpose==4.0.9)
#   Downloading fill_voids-2.1.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (6.0 kB)
# Collecting segment_anything (from cellpose==4.0.9)
#   Downloading segment_anything-1.0-py3-none-any.whl.metadata (487 bytes)
# Requirement already satisfied: torch==2.10.0 in /usr/local/lib/python3.12/dist-packages (from torchvision->cellpose==4.0.9) (2.10.0+cu128)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision->cellpose==4.0.9) (11.3.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->cellpose==4.0.9) (3.24.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->cellpose==4.0.9) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->cellpose==4.0.9) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->cellpose==4.0.9) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->cellpose==4.0.9) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->cellpose==4.0.9) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->cellpose==4.0.9) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->cellpose==4.0.9) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->cellpose==4.0.9) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->cellpose==4.0.9) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->cellpose==4.0.9) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->cellpose==4.0.9) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->cellpose==4.0.9) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->cellpose==4.0.9) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->cellpose==4.0.9) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->cellpose==4.0.9) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->cellpose==4.0.9) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->cellpose==4.0.9) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->cellpose==4.0.9) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->cellpose==4.0.9) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->cellpose==4.0.9) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->cellpose==4.0.9) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->cellpose==4.0.9) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->cellpose==4.0.9) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch==2.10.0->torchvision->cellpose==4.0.9) (1.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch==2.10.0->torchvision->cellpose==4.0.9) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch==2.10.0->torchvision->cellpose==4.0.9) (3.0.3)
# Downloading fastremap-1.17.7-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (7.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 76.2 MB/s eta 0:00:00
# Downloading fill_voids-2.1.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 96.8 MB/s eta 0:00:00
# Downloading imagecodecs-2026.1.14-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (24.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.7/24.7 MB 88.5 MB/s eta 0:00:00
# Downloading roifile-2026.2.10-py3-none-any.whl (21 kB)
# Downloading segment_anything-1.0-py3-none-any.whl (36 kB)
# Building wheels for collected packages: cellpose
#   Building wheel for cellpose (setup.py) ... done
#   Created wheel for cellpose: filename=cellpose-4.0.9-py3-none-any.whl size=212966 sha256=5e8859e7a5d9a4cad3a7d9ff9f0bffc208a3f28934cec9d2398e0b9d2be53341
#   Stored in directory: /tmp/pip-ephem-wheel-cache-hfss8vym/wheels/df/b6/31/a3013c44290eabb46f4c06d1efb19744124fcad2d59684ec5e
# Successfully built cellpose
# Installing collected packages: segment_anything, roifile, imagecodecs, fastremap, fill-voids, cellpose
# Successfully installed cellpose-4.0.9 fastremap-1.17.7 fill-voids-2.1.1 imagecodecs-2026.1.14 roifile-2026.2.10 segment_anything-1.0

# %% [markdown]
# Check GPU and instantiate model - will download weights.

# %%
import numpy as np
from cellpose import models, core, io, plot
from pathlib import Path
from tqdm import trange
import matplotlib.pyplot as plt
from natsort import natsorted

io.logger_setup() # run this to get printing of progress

#Check if colab notebook instance has GPU access
if core.use_gpu()==False:
  raise ImportError("No GPU access, change your runtime")

modelpath = "/content/drive/MyDrive/Data for Colab/models/cpsam_20260225_113048"

model = models.CellposeModel(gpu=True)
#model = models.CellposeModel(gpu=True, pretrained_model=modelpath)
# Out:
# creating new log file
# 2026-03-06 14:51:08,065 [INFO] WRITING LOG OUTPUT TO /root/.cellpose/run.log
# 2026-03-06 14:51:08,067 [INFO]
# cellpose version: 	4.0.9
# platform:       	linux
# python version: 	3.12.12
# torch version:  	2.10.0+cu128
# 2026-03-06 14:51:08,520 [INFO] ** TORCH CUDA version installed and working. **
# 2026-03-06 14:51:08,521 [INFO] ** TORCH CUDA version installed and working. **
# 2026-03-06 14:51:08,523 [INFO] >>>> using GPU (CUDA)
# 2026-03-06 14:51:11,970 [INFO] Downloading: "https://huggingface.co/mouseland/cellpose-sam/resolve/main/cpsam" to /root/.cellpose/models/cpsam
# 100%|██████████| 1.15G/1.15G [00:05<00:00, 214MB/s]

# %% [markdown]
# Input directory with your images:

# %%
# *** change to your google drive folder path ***
dir = "/content/drive/MyDrive/Data for Colab/images"
dir = Path(dir)
if not dir.exists():
  raise FileNotFoundError("directory does not exist")


# *** change to your image extension ***
image_ext = ".tif"

# list all files
files = natsorted([f for f in dir.glob("*"+image_ext) if "_masks" not in f.name and "_flows" not in f.name])

if(len(files)==0):
  raise FileNotFoundError("no image files found, did you specify the correct folder and extension?")
else:
  print(f"{len(files)} images in folder:")

for f in files:
  print(f.name)
# Out:
# 372 images in folder:
# Controls_roi_3_max_t001.tif
# Controls_roi_3_max_t002.tif
# Controls_roi_3_max_t003.tif
# Controls_roi_3_max_t004.tif
# Controls_roi_3_max_t005.tif
# Controls_roi_3_max_t006.tif
# Controls_roi_3_max_t007.tif
# Controls_roi_3_max_t008.tif
# Controls_roi_3_max_t009.tif
# Controls_roi_3_max_t010.tif
# Controls_roi_3_max_t011.tif
# Controls_roi_3_max_t012.tif
# Controls_roi_3_max_t013.tif
# Controls_roi_3_max_t014.tif
# Controls_roi_3_max_t015.tif
# Controls_roi_3_max_t016.tif
# Controls_roi_3_max_t017.tif
# Controls_roi_3_max_t018.tif
# Controls_roi_3_max_t019.tif
# Controls_roi_3_max_t020.tif
# Controls_roi_3_max_t021.tif
# Controls_roi_3_max_t022.tif
# Controls_roi_3_max_t023.tif
# Controls_roi_3_max_t024.tif
# Controls_roi_3_max_t025.tif
# Controls_roi_4_max_t001.tif
# Controls_roi_4_max_t002.tif
# Controls_roi_4_max_t003.tif
# Controls_roi_4_max_t004.tif
# Controls_roi_4_max_t005.tif
# Controls_roi_4_max_t006.tif
# Controls_roi_4_max_t007.tif
# Controls_roi_4_max_t008.tif
# Controls_roi_4_max_t009.tif
# Controls_roi_4_max_t010.tif
# Controls_roi_4_max_t011.tif
# Controls_roi_4_max_t012.tif
# Controls_roi_4_max_t013.tif
# Controls_roi_4_max_t014.tif
# Controls_roi_4_max_t015.tif
# Controls_roi_4_max_t016.tif
# Controls_roi_4_max_t017.tif
# Controls_roi_4_max_t018.tif
# Controls_roi_4_max_t019.tif
# Controls_roi_4_max_t020.tif
# Controls_roi_4_max_t021.tif
# Controls_roi_4_max_t022.tif
# Controls_roi_4_max_t023.tif
# Controls_roi_4_max_t024.tif
# Controls_roi_4_max_t025.tif
# LATSi_roi_1_max_t000.tif
# LATSi_roi_1_max_t001.tif
# LATSi_roi_1_max_t002.tif
# LATSi_roi_1_max_t003.tif
# LATSi_roi_1_max_t004.tif
# LATSi_roi_1_max_t005.tif
# LATSi_roi_1_max_t006.tif
# LATSi_roi_1_max_t007.tif
# LATSi_roi_1_max_t008.tif
# LATSi_roi_1_max_t009.tif
# LATSi_roi_1_max_t010.tif
# LATSi_roi_1_max_t011.tif
# LATSi_roi_1_max_t012.tif
# LATSi_roi_1_max_t013.tif
# LATSi_roi_1_max_t014.tif
# LATSi_roi_1_max_t015.tif
# LATSi_roi_1_max_t016.tif
# LATSi_roi_1_max_t017.tif
# LATSi_roi_1_max_t018.tif
# LATSi_roi_1_max_t019.tif
# LATSi_roi_1_max_t020.tif
# LATSi_roi_1_max_t021.tif
# LATSi_roi_1_max_t022.tif
# LATSi_roi_1_max_t023.tif
# LATSi_roi_1_max_t024.tif
# LATSi_roi_1_max_t025.tif
# LATSi_roi_1_max_t026.tif
# LATSi_roi_1_max_t027.tif
# LATSi_roi_1_max_t028.tif
# LATSi_roi_1_max_t029.tif
# LATSi_roi_1_max_t030.tif
# LATSi_roi_1_max_t031.tif
# LATSi_roi_1_max_t032.tif
# LATSi_roi_1_max_t033.tif
# LATSi_roi_1_max_t034.tif
# LATSi_roi_1_max_t035.tif
# LATSi_roi_1_max_t036.tif
# LATSi_roi_1_max_t037.tif
# LATSi_roi_1_max_t038.tif
# LATSi_roi_1_max_t039.tif
# LATSi_roi_1_max_t040.tif
# LATSi_roi_1_max_t041.tif
# LATSi_roi_1_max_t042.tif
# LATSi_roi_1_max_t043.tif
# LATSi_roi_1_max_t044.tif
# LATSi_roi_1_max_t045.tif
# LATSi_roi_1_max_t046.tif
# LATSi_roi_1_max_t047.tif
# LATSi_roi_1_max_t048.tif
# LATSi_roi_1_max_t049.tif
# LATSi_roi_1_max_t050.tif
# LATSi_roi_1_max_t051.tif
# LATSi_roi_1_max_t052.tif
# LATSi_roi_1_max_t053.tif
# LATSi_roi_1_max_t054.tif
# LATSi_roi_1_max_t055.tif
# LATSi_roi_1_max_t056.tif
# LATSi_roi_1_max_t057.tif
# LATSi_roi_1_max_t058.tif
# LATSi_roi_1_max_t059.tif
# LATSi_roi_1_max_t060.tif
# LATSi_roi_1_max_t061.tif
# LATSi_roi_1_max_t062.tif
# LATSi_roi_1_max_t063.tif
# LATSi_roi_1_max_t064.tif
# LATSi_roi_1_max_t065.tif
# LATSi_roi_1_max_t066.tif
# LATSi_roi_1_max_t067.tif
# LATSi_roi_1_max_t068.tif
# LATSi_roi_1_max_t069.tif
# LATSi_roi_1_max_t070.tif
# LATSi_roi_1_max_t071.tif
# LATSi_roi_1_max_t072.tif
# LATSi_roi_1_max_t073.tif
# LATSi_roi_1_max_t074.tif
# LATSi_roi_1_max_t075.tif
# LATSi_roi_1_max_t076.tif
# LATSi_roi_1_max_t077.tif
# LATSi_roi_1_max_t078.tif
# LATSi_roi_1_max_t079.tif
# LATSi_roi_1_max_t080.tif
# LATSi_roi_1_max_t081.tif
# LATSi_roi_1_max_t082.tif
# LATSi_roi_1_max_t083.tif
# LATSi_roi_1_max_t084.tif
# LATSi_roi_1_max_t085.tif
# LATSi_roi_1_max_t086.tif
# LATSi_roi_1_max_t087.tif
# LATSi_roi_1_max_t088.tif
# LATSi_roi_1_max_t089.tif
# LATSi_roi_1_max_t090.tif
# LATSi_roi_1_max_t091.tif
# LATSi_roi_1_max_t092.tif
# LATSi_roi_1_max_t093.tif
# LATSi_roi_1_max_t094.tif
# LATSi_roi_1_max_t095.tif
# LATSi_roi_1_max_t096.tif
# LATSi_roi_1_max_t097.tif
# LATSi_roi_1_max_t098.tif
# LATSi_roi_1_max_t099.tif
# LATSi_roi_3_MAX_090.tif
# LATSi_roi_3_MAX_091.tif
# LATSi_roi_3_MAX_092.tif
# LATSi_roi_3_MAX_093.tif
# LATSi_roi_3_MAX_094.tif
# LATSi_roi_3_MAX_095.tif
# LATSi_roi_3_MAX_096.tif
# LATSi_roi_3_MAX_097.tif
# LATSi_roi_3_MAX_098.tif
# LATSi_roi_3_MAX_099.tif
# LATSi_roi_3_MAX_100.tif
# LATSi_roi_3_MAX_101.tif
# LATSi_roi_3_MAX_102.tif
# LATSi_roi_3_MAX_103.tif
# LATSi_roi_3_MAX_104.tif
# LATSi_roi_3_MAX_105.tif
# LATSi_roi_3_MAX_106.tif
# LATSi_roi_3_MAX_107.tif
# LATSi_roi_3_MAX_108.tif
# LATSi_roi_3_MAX_109.tif
# LATSi_roi_3_MAX_110.tif
# LATSi_roi_3_MAX_111.tif
# LATSi_roi_3_MAX_112.tif
# LATSi_roi_3_MAX_113.tif
# LATSi_roi_3_MAX_114.tif
# LATSi_roi_3_MAX_115.tif
# LATSi_roi_3_MAX_116.tif
# LATSi_roi_3_MAX_117.tif
# LATSi_roi_3_MAX_118.tif
# LATSi_roi_3_MAX_119.tif
# LATSi_roi_3_MAX_120.tif
# LATSi_roi_3_MAX_121.tif
# LATSi_roi_3_MAX_122.tif
# LATSi_roi_3_MAX_123.tif
# LATSi_roi_3_MAX_124.tif
# LATSi_roi_3_MAX_125.tif
# LATSi_roi_3_MAX_126.tif
# LATSi_roi_3_MAX_127.tif
# LATSi_roi_3_MAX_128.tif
# LATSi_roi_3_MAX_129.tif
# LATSi_roi_3_MAX_130.tif
# LATSi_roi_3_MAX_131.tif
# LATSi_roi_3_MAX_132.tif
# LATSi_roi_3_MAX_133.tif
# LATSi_roi_3_MAX_134.tif
# LATSi_roi_3_MAX_135.tif
# LATSi_roi_3_MAX_136.tif
# LATSi_roi_3_MAX_137.tif
# LATSi_roi_3_MAX_138.tif
# LATSi_roi_3_MAX_139.tif
# LATSi_roi_3_MAX_140.tif
# LATSi_roi_3_MAX_141.tif
# LATSi_roi_3_MAX_142.tif
# Z-DEVD cCASP Inh-crop 1_MAX_000.tif
# Z-DEVD cCASP Inh-crop 1_MAX_001.tif
# Z-DEVD cCASP Inh-crop 1_MAX_002.tif
# Z-DEVD cCASP Inh-crop 1_MAX_003.tif
# Z-DEVD cCASP Inh-crop 1_MAX_004.tif
# Z-DEVD cCASP Inh-crop 1_MAX_005.tif
# Z-DEVD cCASP Inh-crop 1_MAX_006.tif
# Z-DEVD cCASP Inh-crop 1_MAX_007.tif
# Z-DEVD cCASP Inh-crop 1_MAX_008.tif
# Z-DEVD cCASP Inh-crop 1_MAX_009.tif
# Z-DEVD cCASP Inh-crop 1_MAX_010.tif
# Z-DEVD cCASP Inh-crop 1_MAX_011.tif
# Z-DEVD cCASP Inh-crop 1_MAX_012.tif
# Z-DEVD cCASP Inh-crop 1_MAX_013.tif
# Z-DEVD cCASP Inh-crop 1_MAX_014.tif
# Z-DEVD cCASP Inh-crop 1_MAX_015.tif
# Z-DEVD cCASP Inh-crop 1_MAX_016.tif
# Z-DEVD cCASP Inh-crop 1_MAX_017.tif
# Z-DEVD cCASP Inh-crop 1_MAX_018.tif
# Z-DEVD cCASP Inh-crop 1_MAX_019.tif
# Z-DEVD cCASP Inh-crop 1_MAX_020.tif
# Z-DEVD cCASP Inh-crop 1_MAX_021.tif
# Z-DEVD cCASP Inh-crop 1_MAX_022.tif
# Z-DEVD cCASP Inh-crop 1_MAX_023.tif
# Z-DEVD cCASP Inh-crop 1_MAX_024.tif
# Z-DEVD cCASP Inh-crop 1_MAX_025.tif
# Z-DEVD cCASP Inh-crop 1_MAX_026.tif
# Z-DEVD cCASP Inh-crop 1_MAX_027.tif
# Z-DEVD cCASP Inh-crop 1_MAX_028.tif
# Z-DEVD cCASP Inh-crop 1_MAX_029.tif
# Z-DEVD cCASP Inh-crop 1_MAX_030.tif
# Z-DEVD cCASP Inh-crop 1_MAX_031.tif
# Z-DEVD cCASP Inh-crop 1_MAX_032.tif
# Z-DEVD cCASP Inh-crop 1_MAX_033.tif
# Z-DEVD cCASP Inh-crop 1_MAX_034.tif
# Z-DEVD cCASP Inh-crop 1_MAX_035.tif
# Z-DEVD cCASP Inh-crop 1_MAX_036.tif
# Z-DEVD cCASP Inh-crop 1_MAX_037.tif
# Z-DEVD cCASP Inh-crop 1_MAX_038.tif
# Z-DEVD cCASP Inh-crop 1_MAX_039.tif
# Z-DEVD cCASP Inh-crop 1_MAX_040.tif
# Z-DEVD cCASP Inh-crop 1_MAX_041.tif
# Z-DEVD cCASP Inh-crop 1_MAX_042.tif
# Z-DEVD cCASP Inh-crop 1_MAX_043.tif
# Z-DEVD cCASP Inh-crop 1_MAX_044.tif
# Z-DEVD cCASP Inh-crop 1_MAX_045.tif
# Z-DEVD cCASP Inh-crop 1_MAX_046.tif
# Z-DEVD cCASP Inh-crop 1_MAX_047.tif
# Z-DEVD cCASP Inh-crop 1_MAX_048.tif
# Z-DEVD cCASP Inh_roi_4_max_t0001.tif
# Z-DEVD cCASP Inh_roi_4_max_t0002.tif
# Z-DEVD cCASP Inh_roi_4_max_t0003.tif
# Z-DEVD cCASP Inh_roi_4_max_t0004.tif
# Z-DEVD cCASP Inh_roi_4_max_t0005.tif
# Z-DEVD cCASP Inh_roi_4_max_t0006.tif
# Z-DEVD cCASP Inh_roi_4_max_t0007.tif
# Z-DEVD cCASP Inh_roi_4_max_t0008.tif
# Z-DEVD cCASP Inh_roi_4_max_t0009.tif
# Z-DEVD cCASP Inh_roi_4_max_t0010.tif
# Z-DEVD cCASP Inh_roi_4_max_t0011.tif
# Z-DEVD cCASP Inh_roi_4_max_t0012.tif
# Z-DEVD cCASP Inh_roi_4_max_t0013.tif
# Z-DEVD cCASP Inh_roi_4_max_t0014.tif
# Z-DEVD cCASP Inh_roi_4_max_t0015.tif
# Z-DEVD cCASP Inh_roi_4_max_t0016.tif
# Z-DEVD cCASP Inh_roi_4_max_t0017.tif
# Z-DEVD cCASP Inh_roi_4_max_t0018.tif
# Z-DEVD cCASP Inh_roi_4_max_t0019.tif
# Z-DEVD cCASP Inh_roi_4_max_t0020.tif
# Z-DEVD cCASP Inh_roi_4_max_t0021.tif
# Z-DEVD cCASP Inh_roi_4_max_t0022.tif
# Z-DEVD cCASP Inh_roi_4_max_t0023.tif
# Z-DEVD cCASP Inh_roi_4_max_t0024.tif
# Z-DEVD cCASP Inh_roi_4_max_t0025.tif
# Z-DEVD cCASP Inh_roi_4_max_t0026.tif
# Z-DEVD cCASP Inh_roi_4_max_t0027.tif
# Z-DEVD cCASP Inh_roi_4_max_t0028.tif
# Z-DEVD cCASP Inh_roi_4_max_t0029.tif
# Z-DEVD cCASP Inh_roi_4_max_t0030.tif
# Z-DEVD cCASP Inh_roi_4_max_t0031.tif
# Z-DEVD cCASP Inh_roi_4_max_t0032.tif
# Z-DEVD cCASP Inh_roi_4_max_t0033.tif
# Z-DEVD cCASP Inh_roi_4_max_t0034.tif
# Z-DEVD cCASP Inh_roi_4_max_t0035.tif
# Z-DEVD cCASP Inh_roi_4_max_t0036.tif
# Z-DEVD cCASP Inh_roi_4_max_t0037.tif
# Z-DEVD cCASP Inh_roi_4_max_t0038.tif
# Z-DEVD cCASP Inh_roi_4_max_t0039.tif
# Z-DEVD cCASP Inh_roi_4_max_t0040.tif
# Z-DEVD cCASP Inh_roi_4_max_t0041.tif
# Z-DEVD cCASP Inh_roi_4_max_t0042.tif
# Z-DEVD cCASP Inh_roi_4_max_t0043.tif
# Z-DEVD cCASP Inh_roi_4_max_t0044.tif
# Z-DEVD cCASP Inh_roi_4_max_t0045.tif
# Z-DEVD cCASP Inh_roi_4_max_t0046.tif
# Z-DEVD cCASP Inh_roi_4_max_t0047.tif
# Z-DEVD cCASP Inh_roi_4_max_t0048.tif
# Z-DEVD cCASP Inh_roi_4_max_t0049.tif
# Z-DEVD cCASP Inh_roi_4_max_t0050.tif
# Z-DEVD cCASP Inh_roi_4_max_t0051.tif
# Z-DEVD cCASP Inh_roi_4_max_t0052.tif
# Z-DEVD cCASP Inh_roi_4_max_t0053.tif
# Z-DEVD cCASP Inh_roi_4_max_t0054.tif
# Z-DEVD cCASP Inh_roi_4_max_t0055.tif
# Z-DEVD cCASP Inh_roi_4_max_t0056.tif
# Z-DEVD cCASP Inh_roi_4_max_t0057.tif
# Z-DEVD cCASP Inh_roi_4_max_t0058.tif
# Z-DEVD cCASP Inh_roi_4_max_t0059.tif
# Z-DEVD cCASP Inh_roi_4_max_t0060.tif
# Z-DEVD cCASP Inh_roi_4_max_t0061.tif
# Z-DEVD cCASP Inh_roi_4_max_t0062.tif
# Z-DEVD cCASP Inh_roi_4_max_t0063.tif
# Z-DEVD cCASP Inh_roi_4_max_t0064.tif
# Z-DEVD cCASP Inh_roi_4_max_t0065.tif
# Z-DEVD cCASP Inh_roi_4_max_t0066.tif
# Z-DEVD cCASP Inh_roi_4_max_t0067.tif
# Z-DEVD cCASP Inh_roi_4_max_t0068.tif
# Z-DEVD cCASP Inh_roi_4_max_t0069.tif
# Z-DEVD cCASP Inh_roi_4_max_t0070.tif
# Z-DEVD_roi_2_max_t000.tif
# Z-DEVD_roi_2_max_t001.tif
# Z-DEVD_roi_2_max_t002.tif
# Z-DEVD_roi_2_max_t003.tif
# Z-DEVD_roi_2_max_t004.tif
# Z-DEVD_roi_2_max_t005.tif
# Z-DEVD_roi_2_max_t006.tif
# Z-DEVD_roi_2_max_t007.tif
# Z-DEVD_roi_2_max_t008.tif
# Z-DEVD_roi_2_max_t009.tif
# Z-DEVD_roi_2_max_t010.tif
# Z-DEVD_roi_2_max_t011.tif
# Z-DEVD_roi_2_max_t012.tif
# Z-DEVD_roi_2_max_t013.tif
# Z-DEVD_roi_2_max_t014.tif
# Z-DEVD_roi_2_max_t015.tif
# Z-DEVD_roi_2_max_t016.tif
# Z-DEVD_roi_2_max_t017.tif
# Z-DEVD_roi_2_max_t018.tif
# Z-DEVD_roi_2_max_t019.tif
# Z-DEVD_roi_2_max_t020.tif
# Z-DEVD_roi_2_max_t021.tif
# Z-DEVD_roi_2_max_t022.tif
# Z-DEVD_roi_2_max_t023.tif
# Z-DEVD_roi_2_max_t024.tif
# Z-DEVD_roi_2_max_t025.tif
# Z-DEVD_roi_2_max_t026.tif
# Z-DEVD_roi_2_max_t027.tif
# Z-DEVD_roi_2_max_t028.tif
# Z-DEVD_roi_2_max_t029.tif
# Z-DEVD_roi_2_max_t030.tif
# Z-DEVD_roi_2_max_t031.tif
# Z-DEVD_roi_2_max_t032.tif
# Z-DEVD_roi_2_max_t033.tif
# Z-DEVD_roi_2_max_t034.tif
# Z-DEVD_roi_2_max_t035.tif
# Z-DEVD_roi_2_max_t036.tif
# Z-DEVD_roi_2_max_t037.tif
# Z-DEVD_roi_2_max_t038.tif
# Z-DEVD_roi_2_max_t039.tif
# Z-DEVD_roi_2_max_t040.tif
# Z-DEVD_roi_2_max_t041.tif
# Z-DEVD_roi_2_max_t042.tif
# Z-DEVD_roi_2_max_t043.tif
# Z-DEVD_roi_2_max_t044.tif
# Z-DEVD_roi_2_max_t045.tif
# Z-DEVD_roi_2_max_t046.tif
# Z-DEVD_roi_2_max_t047.tif
# Z-DEVD_roi_2_max_t048.tif
# Z-DEVD_roi_2_max_t049.tif

# %% [markdown]
# ## Run Cellpose-SAM on one image in folder
#
# Here are some of the parameters you can change:
#
# * ***flow_threshold*** is  the  maximum  allowed  error  of  the  flows  for  each  mask.   The  default  is 0.4.
#     *  **Increase** this threshold if cellpose is not returning as many masks as you’d expect (or turn off completely with 0.0)
#     *   **Decrease** this threshold if cellpose is returning too many ill-shaped masks.
#
# * ***cellprob_threshold*** determines proability that a detected object is a cell.   The  default  is 0.0.
#     *   **Decrease** this threshold if cellpose is not returning as many masks as you’d expect or if masks are too small
#     *   **Increase** this threshold if cellpose is returning too many masks esp from dull/dim areas.
#
# * ***tile_norm_blocksize*** determines the size of blocks used for normalizing the image. The default is 0, which means the entire image is normalized together.
#   You may want to change this to 100-200 pixels if you have very inhomogeneous brightness across your image.

# %%
img = io.imread(files[0])

print(f'your image has shape: {img.shape}. Assuming channel dimension is last with {img.shape[-1]} channels')
# Out:
# your image has shape: (510, 528). Assuming channel dimension is last with 528 channels

# %% [markdown]
# ### Channel Selection:
#
# - Use the dropdowns below to select the _zero-indexed_ channels of your image to segment. The order does not matter. Remember to rerun the cell after you edit the dropdowns.
#
# - If you have a histological image taken in brightfield, you don't need to adjust the channels.
#
# - If you have a fluroescent image with multiple stains, you should choose one channel with a cytoplasm/membrane stain, one channel with a nuclear stain, and set the third channel to `None`. Choosing multiple channels may produce segmentaiton of all the structures in the image. If you have retrained the model on your data with a thrid stain (described below), you can run segmentation with all channels.

# %%
first_channel = '0' # @param ['None', 0, 1, 2, 3, 4, 5]
second_channel = 'None' # @param ['None', 0, 1, 2, 3, 4, 5]
third_channel = 'None' # @param ['None', 0, 1, 2, 3, 4, 5]

# %%
selected_channels = []
for i, c in enumerate([first_channel, second_channel, third_channel]):
  if c == 'None':
    continue
  if int(c) > img.shape[-1]:
    assert False, 'invalid channel index, must have index greater or equal to the number of channels'
  if c != 'None':
    selected_channels.append(int(c))



img_selected_channels = np.zeros_like(img)
#img_selected_channels[:, :, :len(selected_channels)] = img[:, :, selected_channels]
img_selected_channels[:, :len(selected_channels)] = img[:,  selected_channels]


flow_threshold = 0.4
cellprob_threshold = 0.0
tile_norm_blocksize = 0

masks, flows, styles = model.eval(img_selected_channels, batch_size=32, flow_threshold=flow_threshold, cellprob_threshold=cellprob_threshold,
                                  normalize={"tile_norm_blocksize": tile_norm_blocksize})

fig = plt.figure(figsize=(12,5))
plot.show_segmentation(fig, img_selected_channels, masks, flows[0])
plt.tight_layout()
plt.show()
# Out:
# 2026-03-06 14:51:45,656 [INFO] No cell pixels found.

# %% [markdown]
# ## Run Cellpose-SAM on folder of images
#
# if you have many large images, you may want to run them as a loop over images

# %%
masks_ext = ".png" if image_ext == ".png" else ".tif"
for i in trange(len(files)):
    f = files[i]
    img = io.imread(f)
    masks, flows, styles = model.eval(img, batch_size=32, flow_threshold=flow_threshold, cellprob_threshold=cellprob_threshold,
                                  normalize={"tile_norm_blocksize": tile_norm_blocksize})
    io.imsave(dir / (f.stem + "_masks" + masks_ext), masks)
# Out:
# 100%|██████████| 25/25 [01:48<00:00,  4.32s/it]

# %% [markdown]
# if you have small images, you may want to load all of them first and then run, so that they can be batched together on the GPU

# %%
print("loading images")
imgs = [io.imread(files[i]) for i in trange(len(files))]

print("running cellpose-SAM")
masks, flows, styles = model.eval(imgs, batch_size=32, flow_threshold=flow_threshold, cellprob_threshold=cellprob_threshold,
                                  normalize={"tile_norm_blocksize": tile_norm_blocksize})
masks_ext = ".png" if image_ext == ".png" else ".tif"
print("saving masks")
for i in trange(len(files)):
    f = files[i]
    io.imsave(dir / (f.stem + "_masks" + masks_ext), masks[i])
# Out:
# saving masks
# 100%|██████████| 372/372 [00:03<00:00, 95.20it/s]

# %% [markdown]
# to save your masks for ImageJ [in ROI Manager format -- TS], run the following code:

# %%
for i in trange(len(files)):
    f = files[i]
    #masks0 = io.imsave(dir / (f.name + "_masks" + masks_ext))
    io.imsave(dir / (f.name + "_masks" + masks_ext), masks[i])
    #io.save_rois(masks0, f)
    io.save_rois(masks[i], f)
# Out:
# 100%|██████████| 25/25 [00:00<00:00, 57.99it/s]
